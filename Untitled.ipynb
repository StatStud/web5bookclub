# %%
#source: https://towardsdatascience.com/onedrive-as-data-storage-for-python-project-2ff8d2d3a0aa
import base64
def create_onedrive_directdownload (onedrive_link):
    data_bytes64 = base64.b64encode(bytes(onedrive_link, 'utf-8'))
    data_bytes64_String = data_bytes64.decode('utf-8').replace('/','_').replace('+','-').rstrip("=")
    resultUrl = f"https://api.onedrive.com/v1.0/shares/u!{data_bytes64_String}/root/content"
    return resultUrl

# %%
onedrive_link = "https://1drv.ms/x/s!Ahn8anFcbOc7gRXzVILu5OCJqvHG"
onedrive_direct = create_onedrive_directdownload(onedrive_link)

# %%
import pandas as pd

df = pd.read_excel(onedrive_direct, sheet_name='python-test')

# %%
df
# Out:
#                                           title                 author  \
# 0   Antifragile: things that gain from disorder  Nassim Nicholas Taleb
# 1                            the plateau effect           Bob Sullivan
# 2                                   Verbal Judo     George J. Thompson
# 3                           Blue Ocean Strategy             W.Chan Kim
# 4                                How to be Rich          Napolean Hill
# 5                              Instant Analysis     David J. Lieberman
# 6                              Wake up and live         Dorthea Brande
# 7                            Psycho-Cybernetics          Maxwell Maltz
# 8                                       Mastery          Robert Greene
# 9                                       Courage           Ryan Holiday
# 10                                  Loser Think            Scott Adams
# 11                So Good They Can't Ignore You            Cal Newport
#
# ...

# %%
df2 = pd.DataFrame([['billy','john','2022-02-02',
                    '2022-02-09', '2', 'reading']], 
                   columns=['title','author','start date', 
                            'end date', 'year week', 'status'])
pd.concat([df2, df])
# Out:
#                                                 title                 author  \
# 0                                               billy                   john
# 0         Antifragile: things that gain from disorder  Nassim Nicholas Taleb
# 1   How to Decide: Simple Tools for Making Better ...             Annie Duke
# 2   Thinking Better: The Art of the Shortcut in Ma...       Marcus Du Sautoy
# 3   Thinking in Bets: Making Smarter Decisions Whe...             Annie Duke
# 4   How to Make Better Decisions: 14 Smart Tactics...       Damon Zahariades
# 5   This Book Will Make You Dangerous: The Irrever...           Tripp Lanier
# 6                                  the plateau effect                    NaN
# 7                                 the fear of failure                    NaN
# 8                         the art of thinking clearly                    NaN
# 9                               algorithms to live by                    NaN
# ...

# %%
df.to_csv("data.csv")
